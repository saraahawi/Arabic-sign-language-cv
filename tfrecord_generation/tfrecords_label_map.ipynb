# %%
import pandas as pd
import tensorflow as tf
import object_detection
import warnings
warnings.filterwarnings("ignore")
from google.colab import drive
from pycocotools import coco

# %% [markdown]
# # 0. Mounting drive

# %%
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %% [markdown]
# # 1. Create Label Map

# %%
labels = [
    {'name':'أ', 'id':1}, {'name':'ب', 'id':2}, {'name':'ت', 'id':3}, {'name':'ث', 'id':4}, {'name':'ج', 'id':5}, {'name':'ح', 'id':6},
    {'name':'خ', 'id':7}, {'name':'د', 'id':8}, {'name':'ذ', 'id':9}, {'name':'ر', 'id':10}, {'name':'ز', 'id':11}, {'name':'س', 'id':12},
    {'name':'ش', 'id':13}, {'name':'ص', 'id':14}, {'name':'ض', 'id':15}, {'name':'ط', 'id':16}, {'name':'ظ', 'id':17}, {'name':'ع', 'id':18},
    {'name':'غ', 'id':19}, {'name':'ف', 'id':20}, {'name':'ق', 'id':21}, {'name':'ك', 'id':22}, {'name':'ل', 'id':23}, {'name':'م', 'id':24},
    {'name':'ن', 'id':25}, {'name':'ه', 'id':26}, {'name':'و', 'id':27}, {'name':'ي', 'id':28}, {'name':'ال', 'id':29}, {'name':'ة', 'id':30}, 
    {'name':'لا', 'id':31}, {'name':'ئ', 'id':32}
]
with open('/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 2. Create TF records

# %%
# !python '/mydrive/customTF2/tfrecord_generation/generate_tfrecord.py' -x '/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/images/train' -l '/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/label_map.pbtxt' -o '/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/train.record'
# !python '/mydrive/customTF2/tfrecord_generation/generate_tfrecord.py' -x '/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/images/test' -l '/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/label_map.pbtxt' -o '/mydrive/Real-Time-ASL-Interpretor-cv/tfrecord_generation/test.record'
